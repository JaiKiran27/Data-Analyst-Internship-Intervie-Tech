# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/Practice dataset 5.csv')
df = data

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
#                           age  hypertension  heart_disease       bmi  \
# age                  1.000000      0.251171       0.233354  0.337396
# hypertension         0.251171      1.000000       0.121262  0.147666
# heart_disease        0.233354      0.121262       1.000000  0.061198
# bmi                  0.337396      0.147666       0.061198  1.000000
# HbA1c_level          0.101354      0.080939       0.067589  0.082997
# blood_glucose_level  0.110672      0.084429       0.070066  0.091261
# diabetes             0.258008      0.197823       0.171727  0.214357
#
#                      HbA1c_level  blood_glucose_level  diabetes
# age                     0.101354             0.110672  0.258008
# hypertension            0.080939             0.084429  0.197823
# heart_disease           0.067589             0.070066  0.171727
# bmi                     0.082997             0.091261  0.214357
# HbA1c_level             1.000000             0.166733  0.400660
# ...

# %%
plt.hist(df.gender, bins=3, edgecolor='k')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
plt.scatter(x=df['gender'], y=df['smoking_history'], c='g', marker='x', label='Data')
plt.xlabel('Gender')
plt.ylabel('smoking_history')
plt.title('Scatter Plot')
plt.legend()
plt.show()

# %%
plt.bar(df.gender,df.age, color='skyblue')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Vertical Bar Chart')
plt.show()

# %%
plt.barh(df.gender,df.age, color='skyblue')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Horizontal Bar Chart')
plt.show()

# %%
plt.boxplot(df.age)
plt.ylabel('Age')
plt.title('Box Plot')
plt.show()

# %%
sns.boxplot(y=df.HbA1c_level,width=0.2)
plt.ylabel('HbA1c_level')
plt.title('Box Plot')
plt.show()

# %%
plt.plot(df.gender,df.age,linestyle='-',marker='x',markerfacecolor='blue', color='lightblue', label='Data')
plt.ylabel('Heart_disease rate')
plt.xlabel('Gender')
plt.title('Line Chart')
plt.legend()
plt.show()

# %%
data = pd.read_csv('/content/supermarket_sales - Sheet1.csv')

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
plt.plot(data.Rating,marker='x',markerfacecolor='blue', color='lightblue', label='Data')
plt.ylabel('Rating')
plt.xlabel('Customers')
plt.title('Line Chart')
plt.legend()
plt.show()
